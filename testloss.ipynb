# %%
import importlib
import plot
importlib.reload(plot)

# %%
exp_header_dict = {
    "alpha0.1": "",
    "alpha0.2": "",
    "alpha0.8": "",
    "alpha0.9": "",
    "alpha0.65": "",
}

param_dict = {
     "alpha0.1": ".1",
    "alpha0.2": ".2",
    "alpha0.8": ".8",
    "alpha0.9": ".9",
    "alpha0.65": ".65",
}

plot.plot_entropy_vs_parameter(
    exp_header_dict,
    param_dict,
    title_notes="(MoE Load Balancing Study)"
)
