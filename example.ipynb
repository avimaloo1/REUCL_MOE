# %% [markdown]
# ## Sample Experiment Analyzer Notebook

# %%
import importlib
import plot
importlib.reload(plot)
# Out:
# <module 'plot' from '/home/amaloo/reucl_moe/plots/plot.py'>

# %%
test_dict={
    "20241122_C044803M": "Expert=1",
    "20241122_C044823H": "Expert=4",
    "20241122_C044916P": "Expert=8",
}
plot.compare_plots(test_dict, metric=('tr_loss', 2), title_notes="trloss")
plot.compare_plots(test_dict, metric=('theory_stats', 20), title_notes="cum.fgt/#.round", ls=True)
plot.plot_discrete_data(test_dict, criteria=16, title_notes="test_loss@round/#.round", ls=True)
plot.compare_plots(test_dict, metric=('theory_stats', 10), title_notes="test_accuracy@round")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       1 test_dict={
#       2     "20241122_C044803M": "Expert=1",
#       3     "20241122_C044823H": "Expert=4",
#       4     "20241122_C044916P": "Expert=8",
#       5 }
# ----> 6 plot.compare_plots(test_dict, metric=('tr_loss', 2), title_notes="trloss")
#       7 plot.compare_plots(test_dict, metric=('theory_stats', 20), title_notes="cum.fgt/#.round", ls=True)
#       8 plot.plot_discrete_data(test_dict, criteria=16, title_notes="test_loss@round/#.round", ls=True)
#
# File ~/reucl_moe/plots/plot.py:143, in compare_plots(exp_header_dict, title_notes, metric, ls)
#     142 def compare_plots(exp_header_dict, title_notes="", metric=('tr_loss', 2), ls=False):
# --> 143     _plot_testing_accuracy(exp_header_dict, title_notes=title_notes, typestr=metric[0], criteria=metric[1], ls=ls)
#
# File ~/reucl_moe/plots/plot.py:111, in _plot_testing_accuracy(exp_header_dict, is_transparent, title_notes, ref_acc, typestr, criteria, ls, is_export, export_g, export_filename)
#     108     plt.figure(figsize=(10, 6),dpi=300, facecolor='white')
#     110 for exp_header, note in exp_header_dict.items():
# --> 111     data = _get_tr_loss(exp_header, typestr=typestr, criteria=criteria)
#     112     data_x = list(range(1,len(data)+1))
#     113     conv_idx = _get_conv_index(exp_header)
#
# File ~/reucl_moe/plots/plot.py:12, in _get_tr_loss(exp_header, typestr, criteria)
#      11 def _get_tr_loss(exp_header, typestr='theory_stats', criteria=2):
# ---> 12     d=np.load(f'{PATH_EXPLOG_PREFIX}/tmoecl/log/{exp_header}/stats_run_0.npz')[typestr]
#      13     return d[:, criteria].tolist()
#
# File ~/miniconda3/envs/aiedgereu_proj/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453     own_fid = False
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#     458 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/amaloo/reucl_moe/.exp_result//tmoecl/log/20241122_C044803M/stats_run_0.npz'
