# %%
import importlib
import plot
importlib.reload(plot)
# Out:
# <module 'plot' from '/home/amaloo/reucl_moe/plots/plot.py'>

# %%
# %matplotlib inline
exp_header_dict = {
    "alpha0.1": "",
    "alpha0.2": "",
    "alpha0.8": "",
    "alpha0.9": "",
    "alpha0.65": "",
}

param_dict = {
     "alpha0.1": ".1",
    "alpha0.2": ".2",
    "alpha0.8": ".8",
    "alpha0.9": ".9",
    "alpha0.65": ".65",
}

plot.plot_entropy_vs_parameter(
    exp_header_dict,
    param_dict,
    'alpha',
    title_notes="(MoE Load Balancing Study)"
)

# %%
# %matplotlib inline
exp_header_dict = {
    "eta0.01": "",
    "eta0.03": "",
    "eta0.05": "",
    "eta0.9": "",
}

param_dict = {
     "eta0.01": ".01",
    "eta0.03": ".03",
    "eta0.05": ".05",
    "eta0.9": ".9",
}

plot.plot_entropy_vs_parameter(
    exp_header_dict,
    param_dict,
    'eta',
    title_notes="(MoE Load Balancing Study)"
)

# %%
# %matplotlib inline
exp_header_dict = {
    "lambda0.1": "",

    "lambda0.01": "",
 
    "lambda0.001": "",
}

param_dict = {
    "lambda0.1": ".1",
    "lambda0.01": ".01",
    "lambda0.001": ".001",

}

plot.plot_entropy_vs_parameter(
    exp_header_dict,
    param_dict,
    'lambda',
    title_notes="(MoE Load Balancing Study)"
)

# %%
# %matplotlib inline
exp_header_dict = {
    "sigma0.1": "",
    "sigma0.05": "",
    "sigma0.25": "",
    "sigma0.025": ""
}

param_dict = {
    "sigma0.1": ".1",
    "sigma0.05": ".05",
    "sigma0.25": ".25",
    "sigma0.025": ".025"
}

plot.plot_entropy_vs_parameter(
    exp_header_dict,
    param_dict,
    'eta',
    title_notes="(MoE Load Balancing Study)"
)
