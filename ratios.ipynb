# %%
import importlib
import plot
importlib.reload(plot)

# %%
# %matplotlib inline

test_dict = {
    "alpha0.1": "",
    "alpha0.2": "",
    "alpha0.8": "",
    "alpha0.9": "",
    "alpha0.65": "",
}

param_dict = {
     "alpha0.1": ".1",
    "alpha0.2": ".2",
    "alpha0.8": ".8",
    "alpha0.9": ".9",
    "alpha0.65": ".65",
}


plot.plot_expert_load_ratio_vs_parameter(test_dict, param_dict, 'alpha', title_notes="Expert Load Ratio vs _alpha")

# %%
# %matplotlib inline

test_dict = {
    "sigma0.1": "",
    "sigma0.5": "",
    "sigma0.05": "",
    "sigma0.25": "",
    "sigma0.025": "",
}

test_dict = {
    "sigma0.1": ".1",
    "sigma0.5": ".5",
    "sigma0.05": ".05",
    "sigma0.25": ".25",
    "sigma0.025": ".025",
}


plot.plot_expert_load_ratio_vs_parameter(test_dict, param_dict, 'alpha', title_notes="Expert Load Ratio vs _alpha")
